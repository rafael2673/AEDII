# %% [markdown]
# <a href="https://colab.research.google.com/github/rafael2673/AEDII/blob/main/U3T1/generate_graph_sherlock.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Getting Wikipedia Data

# %%
# !pip install wikipedia

# %%
import wikipedia as wiki

# %%
search_string = 'Social Network Analysis'

page = wiki.page(search_string)

content = page.content

content[0:680]

# %%
links = page.links

links[0:10]

# %%
# use this if get error on next cell

import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
import pandas as pd

url = 'https://en.wikipedia.org/wiki/Social_network_analysis'

data = pd.read_html(url)

type(data)

# %%
len(data)

# %%
data

# %%
data[0]

# %%
data[1]

# %%
url = 'https://en.wikipedia.org/wiki/Crime_in_Oregon'

data = pd.read_html(url)

df = data[1]

df.tail()

# %%
data[1]

# %%
type(data)

# %%
type(df)

# %% [markdown]
# # Project Gutenberg

# %%
# !pip install nltk --upgrade --force-reinstall
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 491.3 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 1.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 25.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 792.7/792.7 kB 15.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 4.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.8/301.8 kB 16.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 3.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.67.1
#     Uninstalling tqdm-4.67.1:
#       Successfully uninstalled tqdm-4.67.1
#   Attempting uninstall: regex
#     Found existing installation: regex 2024.11.6
#     Uninstalling regex-2024.11.6:
#       Successfully uninstalled regex-2024.11.6
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.4.2
# ...

# %%
import nltk

nltk.download('gutenberg')
# Out:
# [nltk_data] Downloading package gutenberg to /root/nltk_data...
# [nltk_data]   Unzipping corpora/gutenberg.zip.
# True

# %%
nltk.__version__
# Out:
# '3.9.1'

# %%
from nltk.corpus import gutenberg


gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
file = 'blake-poems.txt'

data = gutenberg.raw(file)

data[0:600]

# %%
# WARNING: do not crawl Gutenberg aggressively; load one book, don't download all, else IP may get blocked

import requests

url = 'https://www.gutenberg.org/cache/epub/1661/pg1661.txt'

data = requests.get(url).text

data
# Out:
# '\ufeffThe Project Gutenberg eBook of The Adventures of Sherlock Holmes\r\n    \r\nThis ebook is for the use of anyone anywhere in the United States and\r\nmost other parts of the world at no cost and with almost no restrictions\r\nwhatsoever. You may copy it, give it away or re-use it under the terms\r\nof the Project Gutenberg License included with this ebook or online\r\nat www.gutenberg.org. If you are not located in the United States,\r\nyou will have to check the laws of the country where you are located\r\nbefore using this eBook.\r\n\r\nTitle: The Adventures of Sherlock Holmes\r\n\r\nAuthor: Arthur Conan Doyle\r\n\r\nRelease date: March 1, 1999 [eBook #1661]\r\n                Most recently updated: October 10, 2023\r\n\r\nLanguage: English\r\n\r\nCredits: an anonymous Project Gutenberg volunteer and Jose Menendez\r\n\r\n\r\n*** START OF THE PROJECT GUTENBERG EBOOK THE ADVENTURES OF SHERLOCK HOLMES ***\r\n\r\n\r\n\r\n\r\nThe Adventures of Sherlock Holmes\r\n\r\nby Arthur Cona
# ...

# %%
url = 'http://english.ryukyushimpo.jp/'

data = requests.get(url).text

data

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(data, 'html.parser')

links = soup.find_all('a', href=True)

links

# %%
len(links)

# %%
url = 'http://english.ryukyushimpo.jp/2021/09/03/34020/'

data = requests.get(url).text

soup = BeautifulSoup(data, 'html.parser')

soup.get_text()

# %%
text = soup.get_text()

text[0:500]

# %%
text = text.replace('\n', ' ').replace('\r', ' ').replace('\t', ' ').replace('\xa0', ' ')

text

# %%
cutoff = text.index('Go to Japanese')

cutoff

# %%
text = text[0:cutoff]

# %%
cutoff = text.rindex('Hirokazu Ueyonabaru')

text = text[cutoff:]

# %%
text

# %% [markdown]
# # NLTK Part-of-Speech Tagging (Pos-Tagging)

# %%
url = 'https://www.gutenberg.org/cache/epub/1661/pg1661.txt'

text = requests.get(url).text

# %%
cutoff = text.index('To Sherlock Holmes')

text = text[cutoff:]
text
# Out:
# 'To Sherlock Holmes she is always _the_ woman. I have seldom heard him\r\nmention her under any other name. In his eyes she eclipses and\r\npredominates the whole of her sex. It was not that he felt any emotion\r\nakin to love for Irene Adler. All emotions, and that one particularly,\r\nwere abhorrent to his cold, precise but admirably balanced mind. He\r\nwas, I take it, the most perfect reasoning and observing machine that\r\nthe world has seen, but as a lover he would have placed himself in a\r\nfalse position. He never spoke of the softer passions, save with a gibe\r\nand a sneer. They were admirable things for the observer—excellent for\r\ndrawing the veil from men’s motives and actions. But for the trained\r\nreasoner to admit such intrusions into his own delicate and finely\r\nadjusted temperament was to introduce a distracting factor which might\r\nthrow a doubt upon all his mental results. Grit in a sensitive\r\ninstrument, or a crack in one of his own high-power lenses, wou
# ...

# %%
cutoff = text.rindex('*** END OF THE PROJECT GUTENBERG EBOOK THE ADVENTURES OF SHERLOCK HOLMES ***')

text = text[:cutoff]

# %%
text[-500:]
# Out:
# 'Mr.\r\nFowler and Miss Rucastle were married, by special license, in\r\nSouthampton the day after their flight, and he is now the holder of a\r\ngovernment appointment in the island of Mauritius. As to Miss Violet\r\nHunter, my friend Holmes, rather to my disappointment, manifested no\r\nfurther interest in her when once she had ceased to be the centre of\r\none of his problems, and she is now the head of a private school at\r\nWalsall, where I believe that she has met with considerable success.\r\n\r\n\r\n\r\n\r\n\r\n\r\n'

# %%
text = text.replace('\r', ' ').replace('\n', ' ')

text[0:505]
# Out:
# 'To Sherlock Holmes she is always _the_ woman. I have seldom heard him  mention her under any other name. In his eyes she eclipses and  predominates the whole of her sex. It was not that he felt any emotion  akin to love for Irene Adler. All emotions, and that one particularly,  were abhorrent to his cold, precise but admirably balanced mind. He  was, I take it, the most perfect reasoning and observing machine that  the world has seen, but as a lover he would have placed himself in a  false position. '

# %%
text = text.replace('â\x80\x99', '\'').replace('â\x80\x9c', '"').replace('â\x80\x9d', '""').replace('â\x80\x94', ' ')

text[0:502]
# Out:
# 'To Sherlock Holmes she is always _the_ woman. I have seldom heard him  mention her under any other name. In his eyes she eclipses and  predominates the whole of her sex. It was not that he felt any emotion  akin to love for Irene Adler. All emotions, and that one particularly,  were abhorrent to his cold, precise but admirably balanced mind. He  was, I take it, the most perfect reasoning and observing machine that  the world has seen, but as a lover he would have placed himself in a  false positio'

# %%
def get_data():

    url = 'https://www.gutenberg.org/cache/epub/1661/pg1661.txt'
    text = requests.get(url).text

    # strip header junk
    cutoff = text.index('To Sherlock Holmes')
    text = text[cutoff:]

    # strip footer junk
    cutoff = text.rindex('*** END OF THE PROJECT GUTENBERG EBOOK THE ADVENTURES OF SHERLOCK HOLMES ***')
    text = text[:cutoff]

    # pre-processing to clean the text
    text = text.replace('\r', ' ').replace('\n', ' ')
    text = text.replace('_', '').replace('--', '')
    text = text.replace('—', ' ').replace('  ', ' ')
    text = text.replace('â\x80\x99', '\'').replace('â\x80\x9c', '"')\
        .replace('â\x80\x9d', '""').replace('â\x80\x94', ' ')

    return text

# %%
text = get_data()

text[0:502]
# Out:
# 'To Sherlock Holmes she is always the woman. I have seldom heard him mention her under any other name. In his eyes she eclipses and predominates the whole of her sex. It was not that he felt any emotion akin to love for Irene Adler. All emotions, and that one particularly, were abhorrent to his cold, precise but admirably balanced mind. He was, I take it, the most perfect reasoning and observing machine that the world has seen, but as a lover he would have placed himself in a false position. He nev'

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
from nltk.tokenize import sent_tokenize

sentences = sent_tokenize(text)

sentences[0:5]
# Out:
# ['To Sherlock Holmes she is always the woman.',
#  'I have seldom heard him mention her under any other name.',
#  'In his eyes she eclipses and predominates the whole of her sex.',
#  'It was not that he felt any emotion akin to love for Irene Adler.',
#  'All emotions, and that one particularly, were abhorrent to his cold, precise but admirably balanced mind.']

# %%
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# True

# %%
import nltk

nltk.pos_tag(sentences)
# Out:
# [('To Sherlock Holmes she is always the woman.', 'NNP'),
#  ('I have seldom heard him mention her under any other name.', 'NNP'),
#  ('In his eyes she eclipses and predominates the whole of her sex.', 'NNP'),
#  ('It was not that he felt any emotion akin to love for Irene Adler.', 'NNP'),
#  ('All emotions, and that one particularly, were abhorrent to his cold, precise but admirably balanced mind.',
#   'NNP'),
#  ('He was, I take it, the most perfect reasoning and observing machine that the world has seen, but as a lover he would have placed himself in a false position.',
#   'NNP'),
#  ('He never spoke of the softer passions, save with a gibe and a sneer.',
#   'NNP'),
#  ('They were admirable things for the observer excellent for drawing the veil from men’s motives and actions.',
#   'NNP'),
# ...

# %%
sentence = sentences[0]

sentence
# Out:
# 'To Sherlock Holmes she is always the woman.'

# %%
from nltk.tokenize import casual_tokenize

tokens = casual_tokenize(sentence)

tokens
# Out:
# ['To', 'Sherlock', 'Holmes', 'she', 'is', 'always', 'the', 'woman', '.']

# %%
nltk.pos_tag(tokens)
# Out:
# [('To', 'TO'),
#  ('Sherlock', 'NNP'),
#  ('Holmes', 'NNP'),
#  ('she', 'PRP'),
#  ('is', 'VBZ'),
#  ('always', 'RB'),
#  ('the', 'DT'),
#  ('woman', 'NN'),
#  ('.', '.')]

# %%
entities = []

for row in nltk.pos_tag(tokens):

    token = row[0]

    tag = row[1]

    if tag == 'NNP':

        entities.append(token)

entities
# Out:
# ['Sherlock', 'Holmes']

# %%
def extract_entities(sentence):

    entities = []

    tokens = casual_tokenize(sentence)

    for row in nltk.pos_tag(tokens):

        token = row[0]

        tag = row[1]

        if tag == 'NNP':

            entities.append(token)

    return entities

# %%
extract_entities(sentence)
# Out:
# ['Sherlock', 'Holmes']

# %%
entities = [extract_entities(sentence) for sentence in sentences]

entities
# Out:
# [['Sherlock', 'Holmes'],
#  [],
#  [],
#  ['Irene', 'Adler'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Grit'],
#  ['Irene', 'Adler'],
#  ['Holmes'],
#  [],
#  ['Holmes', 'Baker', 'Street'],
#  [],
#  ['Odessa', 'Trepoff', 'Atkinson', 'Trincomalee', 'Holland'],
#  [],
#  ['March', 'Baker', 'Street'],
#  ['Study', 'Scarlet', 'Holmes'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Wedlock'],
#  ['Watson', 'Seven'],
#  [],
#  ['Watson'],
#  [],
#  [],
#  ['Holmes', '”'],
#  [],
#  ['Thursday'],
#  ['Mary', 'Jane'],
#  [],
#  [],
#  ['Hence', 'London'],
#  [],
#  [],
#  ['Quite'],
#  [],
#  [],
#  ['Frequently', 'How', '“', 'Well', '“', 'How'],
#  ['“', 'Quite'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['’'],
#  ['Europe'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['’'],
#  [],
#  ['Peculiar', '”', 'Holmes'],
#  [],
#  ['“', 'E', '”', 'P', '”', '“', 'G', '”', '”'],
#  ['Holmes'],
#  [],
#  ['‘',
#   'G',
#   '’',
#   '‘',
#   '’',
# ...

# %%
def extract_entities(sentence):

    entities = []

    tokens = casual_tokenize(sentence)

    for row in nltk.pos_tag(tokens):

        token = row[0]

        tag = row[1]

        if tag == 'NNP':

            entities.append(token)

    if len(entities) > 0:

        return entities

    else:

        return None

# %%
entities = [extract_entities(sentence) for sentence in sentences]

entities[0:10]
# Out:
# [['Sherlock', 'Holmes'],
#  None,
#  None,
#  ['Irene', 'Adler'],
#  None,
#  None,
#  None,
#  None,
#  None,
#  ['Grit']]

# %%
import pandas as pd

df = pd.DataFrame({'sentence':sentences, 'entities':entities})

df.head(10)
# Out:
#                                             sentence            entities
# 0        To Sherlock Holmes she is always the woman.  [Sherlock, Holmes]
# 1  I have seldom heard him mention her under any ...                None
# 2  In his eyes she eclipses and predominates the ...                None
# 3  It was not that he felt any emotion akin to lo...      [Irene, Adler]
# 4  All emotions, and that one particularly, were ...                None
# 5  He was, I take it, the most perfect reasoning ...                None
# 6  He never spoke of the softer passions, save wi...                None
# 7  They were admirable things for the observer ex...                None
# 8  But for the trained reasoner to admit such int...                None
# 9  Grit in a sensitive instrument, or a crack in ...              [Grit]

# %%
df = df.dropna()

df = df[df['entities'].apply(len) > 1]

entities = df['entities'].to_list()

entities
# Out:
# [['Sherlock', 'Holmes'],
#  ['Irene', 'Adler'],
#  ['Irene', 'Adler'],
#  ['Holmes', 'Baker', 'Street'],
#  ['Odessa', 'Trepoff', 'Atkinson', 'Trincomalee', 'Holland'],
#  ['March', 'Baker', 'Street'],
#  ['Study', 'Scarlet', 'Holmes'],
#  ['Watson', 'Seven'],
#  ['Holmes', '”'],
#  ['Mary', 'Jane'],
#  ['Hence', 'London'],
#  ['Frequently', 'How', '“', 'Well', '“', 'How'],
#  ['“', 'Quite'],
#  ['Peculiar', '”', 'Holmes'],
#  ['“', 'E', '”', 'P', '”', '“', 'G', '”', '”'],
#  ['‘',
#   'G',
#   '’',
#   '‘',
#   '’',
#   'Gesellschaft',
#   '’',
#   'Company',
#   '‘',
#   'Co',
#   'P',
#   '’',
#   '‘',
#   'Papier',
#   '‘',
#   'Eg',
#   'Let',
#   'Continental',
#   'Gazetteer'],
#  ['Eglow', 'Eglonitz', 'Egria'],
#  ['Bohemia', 'Carlsbad'],
#  ['Wallenstein', 'Ha'],
#  ['Bohemia', '”'],
#  ['Frenchman', 'Russian'],
#  ['Watson', 'Holmes', 'Doctor'],
#  ['“', 'Never'],
#  ['Sit', 'Doctor'],
#  ['Come', 'Holmes'],
#  ['Pray', '”', 'Holmes'],
#  ['Dr', 'Watson'],
# ...

# %%
def extract_entities(sentence):

    entities = []

    tokens = casual_tokenize(sentence)

    for row in nltk.pos_tag(tokens):

        token = row[0]

        tag = row[1]

        if tag == 'NNP':

            if "'" in token:

                cutoff = token.index('\'')

                token = token[:cutoff]

            entities.append(token)

    if len(entities) > 0:

        return entities

    else:

        return None

# %%
entities = [extract_entities(sentence) for sentence in sentences]

entities
# Out:
# [['Sherlock', 'Holmes'],
#  None,
#  None,
#  ['Irene', 'Adler'],
#  None,
#  None,
#  None,
#  None,
#  None,
#  ['Grit'],
#  ['Irene', 'Adler'],
#  ['Holmes'],
#  None,
#  ['Holmes', 'Baker', 'Street'],
#  None,
#  ['Odessa', 'Trepoff', 'Atkinson', 'Trincomalee', 'Holland'],
#  None,
#  ['March', 'Baker', 'Street'],
#  ['Study', 'Scarlet', 'Holmes'],
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  ['Wedlock'],
#  ['Watson', 'Seven'],
#  None,
#  ['Watson'],
#  None,
#  None,
#  ['Holmes', '”'],
#  None,
#  ['Thursday'],
#  ['Mary', 'Jane'],
#  None,
#  None,
#  ['Hence', 'London'],
#  None,
#  None,
#  ['Quite'],
#  None,
#  None,
#  ['Frequently', 'How', '“', 'Well', '“', 'How'],
#  ['“', 'Quite'],
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  ['’'],
#  ['Europe'],
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  ['’'],
#  None,
#  ['Peculiar', '”', 'Holmes'],
#  None,
# ...

# %%
df = pd.DataFrame({'sentence':sentences, 'entities':entities})

df = df.dropna()

df = df[df['entities'].apply(len) > 1]

entities = df['entities'].to_list()

entities
# Out:
# [['Sherlock', 'Holmes'],
#  ['Irene', 'Adler'],
#  ['Irene', 'Adler'],
#  ['Holmes', 'Baker', 'Street'],
#  ['Odessa', 'Trepoff', 'Atkinson', 'Trincomalee', 'Holland'],
#  ['March', 'Baker', 'Street'],
#  ['Study', 'Scarlet', 'Holmes'],
#  ['Watson', 'Seven'],
#  ['Holmes', '”'],
#  ['Mary', 'Jane'],
#  ['Hence', 'London'],
#  ['Frequently', 'How', '“', 'Well', '“', 'How'],
#  ['“', 'Quite'],
#  ['Peculiar', '”', 'Holmes'],
#  ['“', 'E', '”', 'P', '”', '“', 'G', '”', '”'],
#  ['‘',
#   'G',
#   '’',
#   '‘',
#   '’',
#   'Gesellschaft',
#   '’',
#   'Company',
#   '‘',
#   'Co',
#   'P',
#   '’',
#   '‘',
#   'Papier',
#   '‘',
#   'Eg',
#   'Let',
#   'Continental',
#   'Gazetteer'],
#  ['Eglow', 'Eglonitz', 'Egria'],
#  ['Bohemia', 'Carlsbad'],
#  ['Wallenstein', 'Ha'],
#  ['Bohemia', '”'],
#  ['Frenchman', 'Russian'],
#  ['Watson', 'Holmes', 'Doctor'],
#  ['“', 'Never'],
#  ['Sit', 'Doctor'],
#  ['Come', 'Holmes'],
#  ['Pray', '”', 'Holmes'],
#  ['Dr', 'Watson'],
# ...

# %%
from string import punctuation

def extract_entities(sentence):

    entities = []

    tokens = casual_tokenize(sentence)

    for row in nltk.pos_tag(tokens):

        token = row[0]

        tag = row[1]

        if tag == 'NNP':

            for p in punctuation:

                if p in token:

                    cutoff = token.index(p)

                    token = token[:cutoff]

            if len(token) > 1:

                entities.append(token)

    if len(entities) > 0:

        return entities

    else:

        return None

# %%
entities = [extract_entities(sentence) for sentence in sentences]

df = pd.DataFrame({'sentence':sentences, 'entities':entities})

df = df.dropna()

df = df[df['entities'].apply(len) > 1]

entities = df['entities'].to_list()

entities
# Out:
# [['Sherlock', 'Holmes'],
#  ['Irene', 'Adler'],
#  ['Irene', 'Adler'],
#  ['Holmes', 'Baker', 'Street'],
#  ['Odessa', 'Trepoff', 'Atkinson', 'Trincomalee', 'Holland'],
#  ['March', 'Baker', 'Street'],
#  ['Study', 'Scarlet', 'Holmes'],
#  ['Watson', 'Seven'],
#  ['Mary', 'Jane'],
#  ['Hence', 'London'],
#  ['Frequently', 'How', 'Well', 'How'],
#  ['Peculiar', 'Holmes'],
#  ['Gesellschaft',
#   'Company',
#   'Co',
#   'Papier',
#   'Eg',
#   'Let',
#   'Continental',
#   'Gazetteer'],
#  ['Eglow', 'Eglonitz', 'Egria'],
#  ['Bohemia', 'Carlsbad'],
#  ['Wallenstein', 'Ha'],
#  ['Frenchman', 'Russian'],
#  ['Watson', 'Holmes', 'Doctor'],
#  ['Sit', 'Doctor'],
#  ['Come', 'Holmes'],
#  ['Pray', 'Holmes'],
#  ['Dr', 'Watson'],
#  ['Count', 'Von', 'Kramm'],
#  ['House', 'Ormstein', 'Bohemia', 'Holmes'],
#  ['Majesty',
#   'Wilhelm',
#   'Gottsreich',
#   'Sigismond',
#   'von',
#   'Ormstein',
#   'Grand',
#   'Duke',
#   'Cassel',
#   'King',
#   'Bohemia'],
#  ['Prague', 'Holmes'],
# ...

# %%
def get_book_entities():

    text = get_data()

    sentences = sent_tokenize(text)

    entities = [extract_entities(sentence) for sentence in sentences]

    df = pd.DataFrame({'sentence':sentences, 'entities':entities})

    df = df.dropna()

    df = df[df['entities'].apply(len) > 1]

    entities = df['entities'].to_list()

    return entities,df

# %%
entities, df = get_book_entities()

entities[0:5]
# Out:
# [['Sherlock', 'Holmes'],
#  ['Irene', 'Adler'],
#  ['Irene', 'Adler'],
#  ['Holmes', 'Baker', 'Street'],
#  ['Odessa', 'Trepoff', 'Atkinson', 'Trincomalee', 'Holland']]

# %%
df
# Out:
#                                                sentence  \
# 0           To Sherlock Holmes she is always the woman.
# 3     It was not that he felt any emotion akin to lo...
# 10    And yet there was but one woman to him, and th...
# 13    My own complete happiness, and the home-centre...
# 15    From time to time I heard some vague account o...
# ...                                                 ...
# 4697  “And in this way he managed that your good man...
# 4698  And here comes the country surgeon and Mrs. Ru...
# 4699  Mr. Rucastle survived, but was always a broken...
# 4701  Mr. Fowler and Miss Rucastle were married, by ...
# 4702  As to Miss Violet Hunter, my friend Holmes, ra...
#
#                                                entities
# 0                                    [Sherlock, Holmes]
# 3                                        [Irene, Adler]
# 10                                       [Irene, Adler]
# 13                              [Holmes, Baker, Street]
# ...

# %% [markdown]
# # spaCy Pos-Tagging

# %%
# !python -m spacy download en_core_web_md
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 MB 12.8 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_md')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import spacy

nlp = spacy.load("en_core_web_md")

# %%
def get_data():

    url = 'https://www.gutenberg.org/cache/epub/1661/pg1661.txt'
    text = requests.get(url).text

    # strip header junk
    cutoff = text.index('To Sherlock Holmes')
    text = text[cutoff:]

    # strip footer junk
    cutoff = text.rindex('*** END OF THE PROJECT GUTENBERG EBOOK THE ADVENTURES OF SHERLOCK HOLMES ***')
    text = text[:cutoff]

    # pre-processing to clean the text
    text = text.replace('\r', ' ').replace('\n', ' ')
    text = text.replace('_', '').replace('--', '')
    text = text.replace('—', ' ').replace('  ', ' ')
    text = text.replace('“Sherlock Holmes,', 'Sherlock Holmes')
    text = text.replace('Sherlock Holmes’,', 'Sherlock Holmes')
    text = text.replace('Sherlock Holmes Esq,', 'Sherlock Holmes')
    text = text.replace('â\x80\x99', '\'').replace('â\x80\x9c', '"').replace('â\x80\x9d', '""').replace('â\x80\x94', ' ')

    return text

# %%
text = get_data()

text[0:279]
# Out:
# 'To Sherlock Holmes she is always the woman. I have seldom heard him mention her under any other name. In his eyes she eclipses and predominates the whole of her sex. It was not that he felt any emotion akin to love for Irene Adler. All emotions, and that one particularly, were a'

# %%
doc = nlp(text)

sentences = list(doc.sents)

# %%
for s in sentences[0:6]:

    print(s)

    print()
# Out:
# To Sherlock Holmes she is always the woman.
#
# I have seldom heard him mention her under any other name.
#
# In his eyes she eclipses and predominates the whole of her sex.
#
# It was not that he felt any emotion akin to love for Irene Adler.
#
# All emotions, and that one particularly, were abhorrent to his cold, precise but admirably balanced mind.
#
# He was, I take it, the most perfect reasoning and observing machine that the world has seen, but as a lover he would have placed himself in a false position.

# %%
for token in sentences[0]:

    print('{}: {}'.format(token.text, token.tag_))
# Out:
# To: IN
# Sherlock: NNP
# Holmes: NNP
# she: PRP
# is: VBZ
# always: RB
# the: DT
# woman: NN
# .: .

# %%
for token in sentences[0]:

    print('{}: {}'.format(token.text, token.pos_))
# Out:
# To: ADP
# Sherlock: PROPN
# Holmes: PROPN
# she: PRON
# is: AUX
# always: ADV
# the: DET
# woman: NOUN
# .: PUNCT

# %%
entities = []

for token in sentences[0]:

    if token.tag_ == 'NNP':

        entities.append(token.text)

entities
# Out:
# ['Sherlock', 'Holmes']

# %%
entities = []

for sentence in sentences:

    sentence_entities = []

    for token in sentence:

        if token.tag_ == 'NNP':

            sentence_entities.append(token.text)

    entities.append(sentence_entities)

entities[0:10]
# Out:
# [['Sherlock', 'Holmes'], [], [], ['Irene', 'Adler'], [], [], [], [], [], []]

# %%
def extract_entities(text):

    doc = nlp(text)

    sentences = list(doc.sents)

    entities = []

    for sentence in sentences:

        sentence_entities = []

        for token in sentence:

            if token.tag_ == 'NNP':

                sentence_entities.append(token.text)

        if len(sentence_entities) > 0:

            entities.append(sentence_entities)

    return entities

# %%
extract_entities(text)
# Out:
# [['Sherlock', 'Holmes'],
#  ['Irene', 'Adler'],
#  ['Irene', 'Adler'],
#  ['Holmes'],
#  ['Holmes', 'Baker', 'Street'],
#  ['Odessa', 'Trepoff', 'Atkinson', 'Trincomalee', 'Holland'],
#  ['March'],
#  ['Baker', 'Street'],
#  ['Study', 'Scarlet', 'Holmes'],
#  ['spirit'],
#  ['Watson'],
#  ['Seven'],
#  ['Watson'],
#  ['Holmes'],
#  ['Thursday'],
#  ['Mary', 'Jane'],
#  ['London'],
#  ['Europe'],
#  ['Holmes'],
#  ['Holmes'],
#  ['German'],
#  ['Co.', 'Papier'],
#  ['Eg'],
#  ['Continental', 'Gazetteer'],
#  ['Eglow', 'Eglonitz', 'Egria'],
#  ['German', 'Bohemia', 'Carlsbad'],
#  ['Wallenstein'],
#  ['Bohemia'],
#  ['German'],
#  ['Frenchman'],
#  ['German'],
#  ['German'],
#  ['Holmes'],
#  ['Watson'],
#  ['Holmes', 'Doctor'],
#  ['Boswell'],
#  ['Doctor'],
#  ['Holmes'],
#  ['Hercules'],
#  ['England'],
#  ['astrakhan'],
#  ['chin'],
#  ['Holmes'],
#  ['Dr.', 'Watson'],
#  ['Count', 'Von', 'Kramm'],
#  ['Holmes'],
#  ['Count'],
#  ['Holmes'],
#  ['august'],
#  ['Holmes'],
# ...

# %% [markdown]
# # spaCy NER

# %%
for token in sentences[0]:

    print('{}: {}'.format(token.text, token.ent_type_))
# Out:
# To: PERSON
# Sherlock: PERSON
# Holmes: PERSON
# she:
# is:
# always:
# the:
# woman:
# .:

# %%
sentences[0].text
# Out:
# 'To Sherlock Holmes she is always the woman.'

# %%
doc = nlp(sentences[0].text)

for ent in doc.ents:

    print('{}: {}'.format(ent, ent.label_))
# Out:
# To Sherlock Holmes: PERSON

# %%
def extract_entities(text):

    doc = nlp(text)

    sentences = list(doc.sents)

    entities = []

    for sentence in sentences:

        sentence_entities = []

        sent_doc = nlp(sentence.text)

        for ent in sent_doc.ents:

            if ent.label_ in ['PERSON', 'ORG', 'GPE']:

                entity = ent.text.strip()

                if "'s" in entity:

                    cutoff = entity.index("'s")

                    entity = entity[:cutoff]

                if entity != '':

                    sentence_entities.append(entity)

        sentence_entities = list(set(sentence_entities))

        if len(sentence_entities) > 1:

            entities.append(sentence_entities)

    return entities

# %%
text
# Out:
# 'To Sherlock Holmes she is always the woman. I have seldom heard him mention her under any other name. In his eyes she eclipses and predominates the whole of her sex. It was not that he felt any emotion akin to love for Irene Adler. All emotions, and that one particularly, were abhorrent to his cold, precise but admirably balanced mind. He was, I take it, the most perfect reasoning and observing machine that the world has seen, but as a lover he would have placed himself in a false position. He never spoke of the softer passions, save with a gibe and a sneer. They were admirable things for the observer excellent for drawing the veil from men’s motives and actions. But for the trained reasoner to admit such intrusions into his own delicate and finely adjusted temperament was to introduce a distracting factor which might throw a doubt upon all his mental results. Grit in a sensitive instrument, or a crack in one of his own high-power lenses, would not be more disturbing than a strong e
# ...

# %%
len(text)
# Out:
# 561332

# %%
adventures_of_holmes_entities = extract_entities(text)

adventures_of_holmes_entities[10:20]
# Out:
# [['Irene Adler', 'Godfrey Norton', 'spinster'],
#  ['fro', 'Holmes'],
#  ['Arnsworth Castle', 'the Darlington Substitution Scandal'],
#  ['Irene Adler', 'Holmes'],
#  ['Irene Adler', 'Sherlock Holmes Esq'],
#  ['Sherlock Holmes', 'NORTON'],
#  ['Sherlock Holmes', 'Bohemia'],
#  ['China', 'Freemason'],
#  ['Holmes', 'Watson'],
#  ['Ezekiah Hopkins', 'Lebanon', 'U.S.A.', 'League', 'Pennsylvania']]

# %%
len(adventures_of_holmes_entities)
# Out:
# 264

# %%
adventures_of_holmes_entities
# Out:
# [['Trepoff', 'Odessa', 'Atkinson', 'Holland', 'Trincomalee'],
#  ['the Study in Scarlet', 'Holmes'],
#  ['Egria', 'Eglow,', 'Eglonitz'],
#  ['Carlsbad', 'Bohemia'],
#  ['House', 'Ormstein', 'Bohemia'],
#  ['Cassel-Felstein',
#   'Wilhelm Gottsreich Sigismond von Ormstein',
#   'Bohemia',
#   'Grand Duke'],
#  ['Irene Adler', 'Warsaw'],
#  ['von Saxe-Meningen', 'Clotilde Lothman'],
#  ['Langham', 'the Count Von Kramm'],
#  ['the Church of St. Monica', 'Gross & Hankey’s'],
#  ['Irene Adler', 'Godfrey Norton', 'spinster'],
#  ['fro', 'Holmes'],
#  ['Arnsworth Castle', 'the Darlington Substitution Scandal'],
#  ['Irene Adler', 'Holmes'],
#  ['Irene Adler', 'Sherlock Holmes Esq'],
#  ['Sherlock Holmes', 'NORTON'],
#  ['Sherlock Holmes', 'Bohemia'],
#  ['China', 'Freemason'],
#  ['Holmes', 'Watson'],
#  ['Ezekiah Hopkins', 'Lebanon', 'U.S.A.', 'League', 'Pennsylvania'],
#  ['Court', 'League', 'Duncan Ross'],
#  ['Jabez Wilson', 'Sherlock Holmes'],
#  ['League', 'I.  “'],
# ...

# %%
def get_data():

    url = 'https://www.gutenberg.org/cache/epub/834/pg834.txt'
    text = requests.get(url).text

    # strip header junk
    cutoff = text.index('I am afraid')
    text = text[cutoff:]

    # strip footer junk
    cutoff = text.rindex('*** END OF THE PROJECT GUTENBERG EBOOK THE MEMOIRS OF SHERLOCK HOLMES ***')
    text = text[:cutoff]

    # pre-processing to clean the text
    text = text.replace('\r', ' ').replace('\n', ' ')
    text = text.replace('_', '').replace('--', '')
    text = text.replace('—', ' ').replace('  ', ' ')
    text= text.replace('     ', ' ').replace('    ', ' ')
    text = text.replace('“Sherlock Holmes,', 'Sherlock Holmes')
    text = text.replace('Sherlock Holmes’,', 'Sherlock Holmes')
    text = text.replace('Sherlock Holmes Esq,', 'Sherlock Holmes')
    text = text.replace('â\x80\x99', '\'').replace('â\x80\x9c', '"').replace('â\x80\x9d', '""').replace('â\x80\x94', ' ')

    return text

# %%
text = get_data()

text[0:310]
# Out:
# 'I am afraid, Watson, that I shall have to go,” said Holmes, as we sat down together to our breakfast one morning. “Go! Where to?” “To Dartmoor; to King’s Pyland.” I was not surprised. Indeed, my only wonder was that he had not already been mixed up in this extraordinary case, which was the one topic of conver'

# %%
memoirs_of_holmes_entities = extract_entities(text)

memoirs_of_holmes_entities[0:10]
# Out:
# [['Holmes', 'Watson'],
#  ['Dartmoor', 'King’s Pyland'],
#  ['I.', 'Watson'],
#  ['Paddington', 'Exeter', 'Sherlock Holmes'],
#  ['John Straker', 'Silver Blaze'],
#  ['Ross', 'Gregory'],
#  ['England', 'Dartmoor'],
#  ['John Straker', 'Ross'],
#  ['Dartmoor', 'Tavistock'],
#  ['Mapleton', 'Tavistock', 'Silas Brown', 'Backwater']]

# %% [markdown]
# # Converting entities to network data

# %%
memoirs_of_holmes_entities[0:10]
# Out:
# [['Holmes', 'Watson'],
#  ['Dartmoor', 'King’s Pyland'],
#  ['I.', 'Watson'],
#  ['Paddington', 'Exeter', 'Sherlock Holmes'],
#  ['John Straker', 'Silver Blaze'],
#  ['Ross', 'Gregory'],
#  ['England', 'Dartmoor'],
#  ['John Straker', 'Ross'],
#  ['Dartmoor', 'Tavistock'],
#  ['Mapleton', 'Tavistock', 'Silas Brown', 'Backwater']]

# %%
final_sources = []
final_targets = []

for row in memoirs_of_holmes_entities:

    source = row[0]
    targets = row[1:]

    for target in targets:

        final_sources.append(source)
        final_targets.append(target)

# %%
final_sources[0:5]
# Out:
# ['Holmes', 'Dartmoor', 'I.', 'Paddington', 'Paddington']

# %%
final_targets[0:5]
# Out:
# ['Watson', 'King’s Pyland', 'Watson', 'Exeter', 'Sherlock Holmes']

# %%
def get_network_data(entities):

    final_sources = []
    final_targets = []

    for row in entities:

        source = row[0]
        targets = row[1:]

        for target in targets:

            final_sources.append(source)
            final_targets.append(target)

    df = pd.DataFrame({'source':final_sources, 'target':final_targets})

    return df

# %%
memoirs_of_holmes_network_df = get_network_data(memoirs_of_holmes_entities)

memoirs_of_holmes_network_df.head()
# Out:
#        source           target
# 0      Holmes           Watson
# 1    Dartmoor    King’s Pyland
# 2          I.           Watson
# 3  Paddington           Exeter
# 4  Paddington  Sherlock Holmes

# %%
adventures_of_holmes_network_df = get_network_data(adventures_of_holmes_entities)

adventures_of_holmes_network_df.head()
# Out:
#                  source       target
# 0               Trepoff       Odessa
# 1               Trepoff     Atkinson
# 2               Trepoff      Holland
# 3               Trepoff  Trincomalee
# 4  the Study in Scarlet       Holmes

# %% [markdown]
# # Converting network data into networks

# %%
import networkx as nx

G_memoirs_of_holmes = nx.from_pandas_edgelist(memoirs_of_holmes_network_df)

G_adventures_of_holmes = nx.from_pandas_edgelist(adventures_of_holmes_network_df)

# %%
print(G_memoirs_of_holmes)
# Out:
# Graph with 268 nodes and 284 edges

# %%
print(G_adventures_of_holmes)
# Out:
# Graph with 310 nodes and 320 edges

# %%
# !pip install scikit-network
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 41.0 MB/s eta 0:00:00
# ...

# %%
nx.to_scipy_sparse_array
# Out:
# <function networkx.convert_matrix.to_scipy_sparse_array(G, nodelist=None, dtype=None, weight='weight', format='csr', *, backend=None, **backend_kwargs)>

# %%
def draw_graph(G, show_names=False, node_size=1, font_size=10, edge_width=0.5):

    import numpy as np
    import networkx as nx

    from IPython.display import SVG
    from sknetwork.visualization import svg_graph
    from sknetwork.data import Bunch
    from sknetwork.ranking import PageRank
    import scipy.sparse as sp

    adjacency = nx.adjacency_matrix(G, weight='weight')
    adjacency = sp.csr_matrix(adjacency)

    names = np.array(list(G.nodes()))

    graph = Bunch()
    graph.adjacency = adjacency
    graph.names = np.array(names)

    pagerank = PageRank()

    pagerank.fit(adjacency)
    scores = pagerank.scores_

    if show_names:

        image = svg_graph(graph.adjacency, font_size=font_size, node_size=node_size, names=graph.names, width=700, height=500, scores=scores, edge_width=edge_width)

    else:

        image = svg_graph(graph.adjacency, node_size=node_size, width=700, height=500, scores = scores, edge_width=edge_width)

    return SVG(image)

# %%
def draw_ego_graph(G, ego, center=True, k=0, show_names=True, edge_width=0.1, node_size=3, font_size=12):

    ego = nx.ego_graph(G, ego, center=center)

    ego = nx.k_core(ego, k)

    return draw_graph(ego, node_size=node_size, font_size=font_size, show_names=show_names, edge_width=edge_width)

# %%
draw_graph(G_memoirs_of_holmes)

# %%
draw_graph(G_memoirs_of_holmes, edge_width=0.2, node_size=3, show_names=True)

# %%
draw_graph(G_memoirs_of_holmes, edge_width=0.2, node_size=2, show_names=True, font_size=12)

# %%
draw_ego_graph(G_memoirs_of_holmes, 'Sherlock Holmes')

# %%
draw_ego_graph(G_memoirs_of_holmes, 'Sherlock Holmes', center=False)

# %%
draw_ego_graph(G_memoirs_of_holmes, 'Sherlock Holmes', center=False, k=1)

# %%
draw_graph(G_adventures_of_holmes, show_names=True, node_size=3, font_size=12)

# %%
adventures_of_holmes_network_df
# Out:
#                    source       target
# 0                 Trepoff       Odessa
# 1                 Trepoff     Atkinson
# 2                 Trepoff      Holland
# 3                 Trepoff  Trincomalee
# 4    the Study in Scarlet       Holmes
# ..                    ...          ...
# 354         Miss Rucastle  Southampton
# 355         Miss Rucastle       Fowler
# 356         Miss Rucastle    Mauritius
# 357         Violet Hunter       Holmes
# 358         Violet Hunter      Walsall
#
# [359 rows x 2 columns]

# %%
adventures_of_holmes_network_df.drop_duplicates()
# Out:
#                    source       target
# 0                 Trepoff       Odessa
# 1                 Trepoff     Atkinson
# 2                 Trepoff      Holland
# 3                 Trepoff  Trincomalee
# 4    the Study in Scarlet       Holmes
# ..                    ...          ...
# 354         Miss Rucastle  Southampton
# 355         Miss Rucastle       Fowler
# 356         Miss Rucastle    Mauritius
# 357         Violet Hunter       Holmes
# 358         Violet Hunter      Walsall
#
# [321 rows x 2 columns]

# %%
import networkx as nx

# Assuming G_adventures_of_holmes and G_memoirs_of_holmes are already defined as in your provided code

# Export graphs to GraphML format
nx.write_graphml(G_adventures_of_holmes, "adventures_of_holmes_network.graphml")
nx.write_graphml(G_memoirs_of_holmes, "memoirs_of_holmes_network.graphml")
